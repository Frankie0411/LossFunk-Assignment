# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install or uv pip install
    # !pip install unsloth vllm
else:
    pass # For Colab / Kaggle, we need extra instructions hidden below \/

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
    except: get_numpy = "numpy"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_tesla_t4 = False
    get_vllm, get_triton = ("vllm==0.10.1", "triton==3.2.0") if is_t4 else ("vllm", "triton")
    # !uv pip install -qqq --upgrade \
        unsloth {get_vllm} {get_numpy} torchvision bitsandbytes xformers transformers
    # !uv pip install -qqq {get_triton}

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Llama 3.1 8B Instruct`, and set parameters

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 32 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct-bnb-4bit",  # ← CHANGED: Smaller model
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.6, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 08-26 05:10:38 [__init__.py:241] Automatically detected platform cuda.
# ERROR 08-26 05:10:40 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Patching vLLM v1 graph capture
# Unsloth: Patching vLLM v0 graph capture
# ==((====))==  Unsloth 2025.8.9: Fast Llama patching. Transformers: 4.55.4. vLLM: 0.10.1.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.31. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/llama-3.2-3b-instruct-bnb-4bit with actual GPU utilization = 59.43%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 1024. Num Sequences = 192.
# Unsloth: vLLM's KV Cache can use up to 6.3 GB. Also swap space = 0 GB.
# Unsloth: Not an error, but `device` is not supported in vLLM. Skipping.
# INFO 08-26 05:10:53 [utils.py:326] non-default args: {'model': 'unsloth/llama-3.2-3b-instruct-bnb-4bit', 'load_format': 'bitsandbytes', 'dtype': torch.float16, 'seed': 0, 'max_model_len': 1024, 'enable_prefix_caching': True, 'swap_space': 0, 'gpu_memory_utilization': 0.5943185064652763, 'max_num_batched_tokens': 1024, 'max_num_seqs': 192, 'max_logprobs': 0, 'disable_log_stats': True, 'quantization': 'bitsandbytes', 'enable_lora': True, 'max_lora_rank': 32, 'compilation_config': {"level":3,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":null,"use_inductor":true,"compile_sizes":null,"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":4,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":null,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":null,"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":null,"local_cache_dir":null}}
# INFO 08-26 05:11:10 [__init__.py:711] Resolved architecture: LlamaForCausalLM
# WARNING 08-26 05:11:10 [__init__.py:2819] Casting torch.bfloat16 to torch.float16.
# INFO 08-26 05:11:10 [__init__.py:1750] Using max model len 1024
# WARNING 08-26 05:11:10 [arg_utils.py:1770] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection'], 'llm_int8_threshold': 6.0}
# INFO 08-26 05:11:11 [llm_engine.py:222] Initializing a V0 LLM engine (v0.10.1) with config: model='unsloth/llama-3.2-3b-instruct-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-3b-instruct-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=bitsandbytes, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/llama-3.2-3b-instruct-bnb-4bit, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":null,"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":4,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":0,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{"enable_fusion":false,"enable_noop":false},"max_capture_size":192,"local_cache_dir":null}, use_cached_outputs=False,
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# INFO 08-26 05:11:14 [cuda.py:384] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 08-26 05:11:14 [cuda.py:433] Using XFormers backend.
# INFO 08-26 05:11:15 [parallel_state.py:1134] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# INFO 08-26 05:11:15 [model_runner.py:1080] Starting to load model unsloth/llama-3.2-3b-instruct-bnb-4bit...
# INFO 08-26 05:11:16 [bitsandbytes_loader.py:742] Loading weights with BitsAndBytes quantization. May take a while ...
# INFO 08-26 05:11:16 [weight_utils.py:296] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# INFO 08-26 05:11:42 [weight_utils.py:312] Time spent downloading weights for unsloth/llama-3.2-3b-instruct-bnb-4bit: 25.976400 seconds
# INFO 08-26 05:11:42 [weight_utils.py:349] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 08-26 05:11:50 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 08-26 05:11:54 [model_runner.py:1112] Model loading took 2.2455 GiB and 34.494739 seconds
# INFO 08-26 05:12:06 [worker.py:295] Memory profiling takes 10.57 seconds
# INFO 08-26 05:12:06 [worker.py:295] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.59) = 8.76GiB
# INFO 08-26 05:12:06 [worker.py:295] model weights take 2.25GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 0.89GiB; the rest of the memory reserved for KV Cache is 5.59GiB.
# INFO 08-26 05:12:07 [executor_base.py:114] # cuda blocks: 3273, # CPU blocks: 0
# INFO 08-26 05:12:07 [executor_base.py:119] Maximum concurrency for 1024 tokens per request: 51.14x
# INFO 08-26 05:12:07 [vllm_utils.py:671] Unsloth: Running patched vLLM v0 `capture_model`.
# INFO 08-26 05:12:07 [model_runner.py:1383] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/27 [00:00<?, ?it/s]
# INFO 08-26 05:12:30 [model_runner.py:1535] Graph capturing finished in 23 secs, took 0.48 GiB
# INFO 08-26 05:12:30 [vllm_utils.py:678] Unsloth: Patched vLLM v0 graph capture finished in 23 secs.
# INFO 08-26 05:12:31 [llm_engine.py:417] init engine (profile, create kv cache, warmup model) took 37.49 seconds
# INFO 08-26 05:12:31 [llm.py:298] Supported_tasks: ['generate']
# Unsloth: Just some info: will skip parsing ['k_norm', 'q_norm', 'pre_feedforward_layernorm', 'post_feedforward_layernorm']
# Unsloth: Just some info: will skip parsing ['k_norm', 'q_norm', 'pre_feedforward_layernorm', 'post_feedforward_layernorm']
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Unsloth 2025.8.9 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
import re
from datasets import load_dataset, Dataset
import random

# %%
MATH_SYSTEM_PROMPT = """
Solve this math problem step by step.
<reasoning>
Show your work and thinking process here.
</reasoning>
<answer>
Provide the final numerical answer here.
</answer>
"""

DIALOGUE_SYSTEM_PROMPT = """
Respond helpfully and conversationally to the user's message.
"""

# %%
def extract_xml_answer(text: str) -> str:
    """Extract answer from XML format"""
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    """Extract answer from GSM8K format (#### answer)"""
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

def extract_number_from_text(text: str) -> float:
    """Extract first number from text, return 0 if none found"""
    import re
    numbers = re.findall(r'-?\d+\.?\d*', text.replace(',', ''))
    if numbers:
        try:
            return float(numbers[0])
        except:
            return 0.0
    return 0.0

# %%
def get_gsm8k_dataset(split="train", max_samples=1000):
    """Load GSM8K math dataset"""
    data = load_dataset('openai/gsm8k', 'main')[split]

    # Limit dataset size for quick experiments
    if max_samples:
        indices = random.sample(range(len(data)), min(max_samples, len(data)))
        data = data.select(indices)

    def format_math_sample(x):
        return {
            'task_type': 'math',
            'prompt': [
                {'role': 'system', 'content': MATH_SYSTEM_PROMPT},
                {'role': 'user', 'content': x['question']}
            ],
            'ground_truth': extract_hash_answer(x['answer']),
            'numerical_answer': extract_number_from_text(extract_hash_answer(x['answer']) or "0")
        }

    return data.map(format_math_sample)

# %%
def get_dialogue_dataset(split="train", max_samples=1000):
    """Load Alpaca dialogue dataset"""
    data = load_dataset('tatsu-lab/alpaca')[split]

    # Limit dataset size for quick experiments
    if max_samples:
        indices = random.sample(range(len(data)), min(max_samples, len(data)))
        data = data.select(indices)

    def format_dialogue_sample(x):
        # Combine instruction and input if input exists
        user_message = x['instruction']
        if x.get('input', '').strip():
            user_message = f"{x['instruction']}\n\nInput: {x['input']}"

        return {
            'task_type': 'dialogue',
            'prompt': [
                {'role': 'system', 'content': DIALOGUE_SYSTEM_PROMPT},
                {'role': 'user', 'content': user_message}
            ],
            'ground_truth': x['output'],
            'numerical_answer': None  # No numerical answer for dialogue
        }

    return data.map(format_dialogue_sample)

# %%
print("Loading datasets...")
math_dataset = get_gsm8k_dataset(max_samples=800)
dialogue_dataset = get_dialogue_dataset(max_samples=800)

print(f"Math dataset: {len(math_dataset)} samples")
print(f"Dialogue dataset: {len(dialogue_dataset)} samples")

# Sample check
print("\n" + "="*50)
print("MATH SAMPLE:")
print("Question:", math_dataset[0]['prompt'][1]['content'][:500] + "...")
print("Answer:", math_dataset[0]['ground_truth'])

print("\n" + "="*50)
print("DIALOGUE SAMPLE:")
print("Instruction:", dialogue_dataset[0]['prompt'][1]['content'][:500] + "...")
print("Expected:", dialogue_dataset[0]['ground_truth'][:1000] + "...")
# Out:
# Loading datasets...
# README.md: 0.00B [00:00, ?B/s]
# main/train-00000-of-00001.parquet:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# main/test-00000-of-00001.parquet:   0%|          | 0.00/419k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001-a09b74b3ef9c3b(…):   0%|          | 0.00/24.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/52002 [00:00<?, ? examples/s]
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Math dataset: 800 samples
# Dialogue dataset: 800 samples
#
# ==================================================
# MATH SAMPLE:
# Question: A man is returning home from work and trying to decide which route to take.  His first route option includes 3 stoplights.  This route will take him 10 minutes if all three lights are green, but each light that is red will add 3 minutes to the trip.  The second route does not include any stoplights and takes 14 minutes.  If the man chooses the first route, how much longer will his trip be if all 3 stoplights are red?...
# Answer: 5
#
# ==================================================
# DIALOGUE SAMPLE:
# Instruction: Create an algorithm that can sort an array of numbers into ascending order.
#
# Input: [5, 2, 8, 1, 4]...
# Expected: """
# Algorithm to sort an array of numbers into ascending order
# """
#
# def sort_ascending(nums):
#     sorted_list = []
#     while nums:
#         lowest = nums[0]
#         for num in nums:
#             if num < lowest:
#                 lowest = num
#         sorted_list.append(lowest)
#         nums.remove(lowest)
#
#     return sorted_list
#
# if __name__ == '__main__':
#     unsorted = [5, 2, 8, 1, 4]
#     print(sort_ascending(unsorted)) #[1, 2, 4, 5, 8]...

# %%
import google.generativeai as genai
import os
from typing import List
import time

GEMINI_API_KEY = "AIzaSyCbZItblcgX2gWn8mXaY0a5X3LhJn37rTo"
genai.configure(api_key=GEMINI_API_KEY)

# Initialize Gemini model
try:
    gemini_model = genai.GenerativeModel('gemini-1.5-flash')  # Fast and cheap model
    print("Gemini API initialized successfully!")
except Exception as e:
    print(f"Gemini API setup failed: {e}")
    print("Please add your API key above!")
# Out:
# Gemini API initialized successfully!

# %%
def evaluate_dialogue_with_gemini(question: str, response: str) -> float:
    """Use Gemini to evaluate dialogue response quality (0-10 scale)"""

    evaluation_prompt = f"""
You are evaluating an AI assistant's response to a user question. Rate the response on a scale of 0-10 based on:
- Helpfulness: Does it answer the question?
- Accuracy: Is the information correct?
- Clarity: Is it easy to understand?
- Completeness: Does it fully address the question?
- Tone: Is it appropriate and professional?

Question: {question}

Response: {response}

Provide ONLY a number between 0-10 (can use decimals like 7.5). No explanation needed.
"""

    try:
        # Call Gemini API
        result = gemini_model.generate_content(evaluation_prompt)

        # Extract numerical score
        score_text = result.text.strip()
        score = float(score_text)

        # Ensure score is in valid range
        score = max(0.0, min(10.0, score))

        return score

    except Exception as e:
        print(f"Gemini evaluation error: {e}")
        return 5.0  # Fallback to neutral score

def batch_evaluate_dialogues(prompts: List, responses: List[str], batch_delay=1.0) -> List[float]:
    """Evaluate multiple responses with rate limiting"""
    scores = []

    for i, (prompt, response) in enumerate(zip(prompts, responses)):
        question = prompt[-1]['content']  # Get user question
        score = evaluate_dialogue_with_gemini(question, response)
        scores.append(score)

        # Rate limiting - don't spam the API
        if i < len(responses) - 1:  # Don't delay after last request
            time.sleep(batch_delay)

        # Progress indicator
        if (i + 1) % 5 == 0:
            print(f"Evaluated {i + 1}/{len(responses)} responses...")

    return scores

# %%
def math_hard_reward(prompts, completions, answer, numerical_answer, **kwargs) -> list[float]:
    """Hard reward for math: Exact match = 1.0, wrong = 0.0"""
    responses = [completion[0]['content'] for completion in completions]
    extracted_answers = [extract_xml_answer(r) for r in responses]

    rewards = []
    for i, extracted in enumerate(extracted_answers):
        # Try exact string match first
        if extracted == answer[i]:
            rewards.append(2.0)
        # Try numerical match as fallback
        elif numerical_answer and numerical_answer[i] is not None:
            extracted_num = extract_number_from_text(extracted)
            if abs(extracted_num - numerical_answer[i]) < 0.01:  # Allow small rounding errors
                rewards.append(2.0)
            else:
                rewards.append(0.0)
        else:
            rewards.append(0.0)

    # Debug print for first completion
    if len(responses) > 0:
        print(f"\n[MATH HARD] Question: {prompts[0][-1]['content'][:60]}...")
        print(f"Expected: {answer[0]} | Got: {extracted_answers[0]} | Reward: {rewards[0]}")

    return rewards

# %%
def dialogue_hard_reward_gemini(prompts, completions, **kwargs) -> list[float]:
    """Hard reward using Gemini: Good (≥7) = 2.0, Poor (<7) = 0.0"""
    responses = [completion[0]['content'] for completion in completions]

    # Get Gemini scores (0-10)
    gemini_scores = batch_evaluate_dialogues(prompts, responses)

    # Convert to hard rewards (binary)
    hard_rewards = [2.0 if score >= 7.0 else 0.0 for score in gemini_scores]

    # Debug print
    if len(responses) > 0:
        print(f"\n[DIALOGUE HARD GEMINI] Score: {gemini_scores[0]:.1f}/10 | Reward: {hard_rewards[0]}")
        print(f"Response: {responses[0][:1000]}...")

    return hard_rewards

# %%
def math_soft_reward(prompts, completions, answer, numerical_answer, **kwargs) -> list[float]:
    """Soft reward for math: Proximity-based continuous scoring"""
    responses = [completion[0]['content'] for completion in completions]
    extracted_answers = [extract_xml_answer(r) for r in responses]

    rewards = []
    for i, extracted in enumerate(extracted_answers):
        if numerical_answer and numerical_answer[i] is not None:
            extracted_num = extract_number_from_text(extracted)
            target_num = numerical_answer[i]

            if target_num == 0:
                # Avoid division by zero
                error = abs(extracted_num - target_num)
                reward = max(0.0, 2.0 - error * 0.1)
            else:
                # Percentage error-based reward
                error_pct = abs(extracted_num - target_num) / abs(target_num)
                reward = max(0.0, 2.0 * (1.0 - min(error_pct, 1.0)))

            rewards.append(reward)
        else:
            # Fallback to string similarity
            if extracted == answer[i]:
                rewards.append(2.0)
            else:
                # Simple character-level similarity
                similarity = len(set(extracted.lower()) & set(answer[i].lower())) / max(len(set(answer[i].lower())), 1)
                rewards.append(similarity * 2.0)

    # Debug print
    if len(responses) > 0:
        print(f"\n[MATH SOFT] Question: {prompts[0][-1]['content'][:60]}...")
        print(f"Expected: {answer[0]} | Got: {extracted_answers[0]} | Reward: {rewards[0]:.2f}")

    return rewards

# %%
def dialogue_soft_reward_gemini(prompts, completions, **kwargs) -> list[float]:
    """Soft reward using Gemini: Continuous 0-2 based on 0-10 score"""
    responses = [completion[0]['content'] for completion in completions]

    # Get Gemini scores (0-10)
    gemini_scores = batch_evaluate_dialogues(prompts, responses)

    # Convert to soft rewards (0-2 scale)
    soft_rewards = [(score / 10.0) * 2.0 for score in gemini_scores]

    # Debug print
    if len(responses) > 0:
        print(f"\n[DIALOGUE SOFT GEMINI] Score: {gemini_scores[0]:.1f}/10 | Reward: {soft_rewards[0]:.2f}")
        print(f"Response: {responses[0][:1000]}...")

    return soft_rewards

# %%
def format_reward_func(completions, **kwargs) -> list[float]:
    """Reward proper XML formatting"""
    responses = [completion[0]['content'] for completion in completions]
    rewards = []

    for response in responses:
        score = 0.0
        if '<reasoning>' in response and '</reasoning>' in response:
            score += 0.25
        if '<answer>' in response and '</answer>' in response:
            score += 0.25
        rewards.append(score)

    return rewards

# %%
def test_gemini_evaluation():
    """Test if Gemini evaluation works"""
    test_question = "What is the capital of France?"
    test_response = "The capital of France is Paris."

    print("Testing Gemini evaluation...")
    score = evaluate_dialogue_with_gemini(test_question, test_response)
    print(f"Test Score: {score}/10")

    if score > 8.0:
        print("Gemini evaluation working well!")
    else:
        print("Gemini evaluation might need adjustment")

# %%
test_gemini_evaluation()
# Out:
# Testing Gemini evaluation...
# Test Score: 10.0/10
# Gemini evaluation working well!

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
from trl import GRPOConfig, GRPOTrainer
import os

max_prompt_length = 256

# %%
base_config = {
    "learning_rate": 5e-6,
    "adam_beta1": 0.9,
    "adam_beta2": 0.99,
    "weight_decay": 0.1,
    "warmup_ratio": 0.1,
    "lr_scheduler_type": "cosine",
    "optim": "paged_adamw_8bit",
    "logging_steps": 1,
    "per_device_train_batch_size": 1,
    "gradient_accumulation_steps": 2,  # Increased for stability
    "num_generations": 4,  # Reduced to save memory
    "max_prompt_length": max_prompt_length,
    "max_completion_length": max_seq_length - max_prompt_length,
    "max_steps": 100,  # Reduced for quick comparison
    "save_steps": 50,
    "max_grad_norm": 0.1,
    "report_to": "none",
}

# %%
math_hard_config = GRPOConfig(
    **base_config,
    output_dir = "outputs/math_hard_rewards",
    run_name = "math_hard_rewards"
)

math_soft_config = GRPOConfig(
    **base_config,
    output_dir = "outputs/math_soft_rewards",
    run_name = "math_soft_rewards"
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %%
dialogue_hard_config = GRPOConfig(
    **base_config,
    output_dir = "outputs/dialogue_hard_rewards",
    run_name = "dialogue_hard_rewards"
)

dialogue_soft_config = GRPOConfig(
    **base_config,
    output_dir = "outputs/dialogue_soft_rewards",
    run_name = "dialogue_soft_rewards"
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %%
# Math reward mappings
MATH_HARD_REWARDS = [math_hard_reward, format_reward_func]
MATH_SOFT_REWARDS = [math_soft_reward, format_reward_func]

# Dialogue reward mappings
DIALOGUE_HARD_REWARDS = [dialogue_hard_reward_gemini, format_reward_func]
DIALOGUE_SOFT_REWARDS = [dialogue_soft_reward_gemini, format_reward_func]

# %%
training_experiments = [
    {
        "name": "Math Hard Rewards",
        "dataset": math_dataset,
        "config": math_hard_config,
        "rewards": MATH_HARD_REWARDS,
        "task_type": "math"
    },
    {
        "name": "Math Soft Rewards",
        "dataset": math_dataset,
        "config": math_soft_config,
        "rewards": MATH_SOFT_REWARDS,
        "task_type": "math"
    },
    {
        "name": "Dialogue Hard Rewards",
        "dataset": dialogue_dataset,
        "config": dialogue_hard_config,
        "rewards": DIALOGUE_HARD_REWARDS,
        "task_type": "dialogue"
    },
    {
        "name": "Dialogue Soft Rewards",
        "dataset": dialogue_dataset,
        "config": dialogue_soft_config,
        "rewards": DIALOGUE_SOFT_REWARDS,
        "task_type": "dialogue"
    }
]

# %%
print("Training Configurations Ready!")
print(f"{len(training_experiments)} experiments planned:")
for exp in training_experiments:
    print(f"   • {exp['name']}: {len(exp['dataset'])} samples")

print(f"\nEach experiment: {base_config['max_steps']} steps")
# Out:
# Training Configurations Ready!
# 4 experiments planned:
#    • Math Hard Rewards: 800 samples
#    • Math Soft Rewards: 800 samples
#    • Dialogue Hard Rewards: 800 samples
#    • Dialogue Soft Rewards: 800 samples
#
# Each experiment: 100 steps

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
from trl import GRPOTrainer
import torch
import time
import json

# %%
training_results = {}

def run_single_experiment(experiment_config):
    """Run a single training experiment"""
    name = experiment_config["name"]
    dataset = experiment_config["dataset"]
    config = experiment_config["config"]
    rewards = experiment_config["rewards"]
    task_type = experiment_config["task_type"]

    print(f"\nStarting: {name}")
    print(f"Dataset: {len(dataset)} samples")
    print(f"Task: {task_type}")
    print(f"Rewards: {len(rewards)} functions")
    print("-" * 50)

    # Create trainer
    trainer = GRPOTrainer(
        model=model,
        processing_class=tokenizer,
        reward_funcs=rewards,
        args=config,
        train_dataset=dataset,
    )

    # Train and track results
    start_time = time.time()
    trainer.train()
    end_time = time.time()

    # Store results
    training_results[name] = {
        "task_type": task_type,
        "training_time": end_time - start_time,
        "final_step": config.max_steps,
        "output_dir": config.output_dir
    }

    print(f"Completed: {name}")
    print(f"Training time: {end_time - start_time:.1f} seconds")
    print(f"Results saved to: {config.output_dir}")

    return trainer

# %%
trained_models = {}

# Option 1: Run all experiments (will take ~2-3 hours)
run_all = False  # Set to True when ready for full run

if run_all:
    for experiment in training_experiments:
        trained_models[experiment["name"]] = run_single_experiment(experiment)

        # Brief pause between experiments
        time.sleep(10)

    print("\nALL EXPERIMENTS COMPLETED!")

else:
    # Option 2: Run just one experiment first (for testing)
    print("TESTING MODE: Running single experiment")
    test_experiment = training_experiments[0]  # Math Hard Rewards

    print(f"Testing with: {test_experiment['name']}")
    trained_models["test"] = run_single_experiment(test_experiment)
# Out:
# TESTING MODE: Running single experiment
# Testing with: Math Hard Rewards
#
# Starting: Math Hard Rewards
# Dataset: 800 samples
# Task: math
# Rewards: 2 functions
# --------------------------------------------------
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 800 | Num Epochs = 1 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 2 x 1) = 8
#  "-____-"     Trainable parameters = 48,627,712 of 3,261,377,536 (1.49% trained)
# [MATH HARD] Question: On Monday, while at work on the farm, Jeremy picks 100 orang...
# Expected: On Monday he picks 100 oranges.
# On Tuesday, they pick thrice as much, which will be 3*100 = <<3*100=300>>300 oranges.
# The total number of oranges picked now is 300+100 = <<300+100=400>>400 oranges.
# On Wednesday, he adds 70 more, which will now be 400+70 = <<470=470>>470 oranges
# #### 470 | Got: 470 | Reward: 2.0
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 58:15, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>entropy</th>
#       <th>rewards / math_hard_reward / mean</th>
#       <th>rewards / math_hard_reward / std</th>
#       <th>rewards / format_reward_func / mean</th>
#       <th>rewards / format_reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.000000</td>
#       <td>1.187500</td>
#       <td>0.962106</td>
#       <td>210.250000</td>
#       <td>117.000000</td>
#       <td>298.000000</td>
#       <td>0.000000</td>
#       <td>210.250000</td>
#       <td>117.000000</td>
#       <td>298.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>1.000000</td>
#       <td>1.069045</td>
#       <td>0.187500</td>
#       <td>0.115728</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>1.437500</td>
#       <td>0.544862</td>
#       <td>190.500000</td>
#       <td>142.000000</td>
#       <td>294.000000</td>
#       <td>0.000000</td>
#       <td>190.500000</td>
#       <td>142.000000</td>
#       <td>294.000000</td>
#       <td>0.000000</td>
#       <td>No Log</td>
#       <td>1.250000</td>
#       <td>1.035098</td>
#       <td>0.187500</td>
#       <td>0.115728</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.281250</td>
#       <td>0.562500</td>
#       <td>246.750000</td>
#       <td>181.000000</td>
#       <td>438.000000</td>
#       <td>0.000000</td>
#       <td>246.750000</td>
#       <td>181.000000</td>
#       <td>438.000000</td>
#       <td>0.000000</td>
#       <td>No Log</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>1.375000</td>
#       <td>1.111625</td>
#       <td>223.750000</td>
#       <td>173.000000</td>
#       <td>296.000000</td>
#       <td>0.000000</td>
#       <td>223.750000</td>
#       <td>173.000000</td>
#       <td>296.000000</td>
#       <td>0.000000</td>
#       <td>No Log</td>
#       <td>1.250000</td>
#       <td>1.035098</td>
#       <td>0.125000</td>
#       <td>0.133631</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>1.687500</td>
#       <td>1.125000</td>
#       <td>192.000000</td>
#       <td>131.000000</td>
#       <td>267.000000</td>
#       <td>0.000000</td>
#       <td>192.000000</td>
#       <td>131.000000</td>
#       <td>267.000000</td>
#       <td>0.000000</td>
#       <td>No Log</td>
#       <td>1.500000</td>
#       <td>0.925820</td>
#       <td>0.187500</td>
#       <td>0.115728</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>-0.000000</td>
#       <td>0.625000</td>
#       <td>0.678054</td>
#       <td>302.500000</td>
#       <td>150.000000</td>
#       <td>578.000000</td>
#       <td>0.000000</td>
#       <td>302.500000</td>
#       <td>150.000000</td>
#       <td>578.000000</td>
#       <td>0.000000</td>
#       <td>No Log</td>
#       <td>0.500000</td>
#       <td>0.925820</td>
#       <td>0.125000</td>
#       <td>0.133631</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>1.625000</td>
#       <td>0.577350</td>
#       <td>198.125000</td>
#       <td>175.000000</td>
#       <td>225.000000</td>
#       <td>0.000000</td>
#       <td>198.125000</td>
#       <td>175.000000</td>
#       <td>225.000000</td>
#       <td>0.000000</td>
#       <td>No Log</td>
#       <td>1.500000</td>
#       <td>0.925820</td>
#       <td>0.125000</td>
#       <td>0.133631</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>1.343750</td>
#       <td>1.160416</td>
#       <td>185.625000</td>
#       <td>113.000000</td>
#       <td>301.000000</td>
#       <td>0.000000</td>
#       <td>185.625000</td>
#       <td>113.000000</td>
#       <td>301.000000</td>
#       <td>0.000012</td>
#       <td>No Log</td>
#       <td>1.250000</td>
#       <td>1.035098</td>
#       <td>0.093750</td>
#       <td>0.129387</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>1.156250</td>
#       <td>0.062500</td>
#       <td>196.250000</td>
#       <td>111.000000</td>
#       <td>368.000000</td>
#       <td>0.000000</td>
#       <td>196.250000</td>
#       <td>111.000000</td>
#       <td>368.000000</td>
#       <td>0.000009</td>
#       <td>No Log</td>
#       <td>1.000000</td>
#       <td>1.069045</td>
#       <td>0.156250</td>
#       <td>0.129387</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>1.656250</td>
#       <td>0.712019</td>
#       <td>171.625000</td>
#       <td>121.000000</td>
#       <td>205.000000</td>
#       <td>0.000000</td>
#       <td>171.625000</td>
#       <td>121.000000</td>
#       <td>205.000000</td>
#       <td>0.000006</td>
#       <td>No Log</td>
#       <td>1.500000</td>
#       <td>0.925820</td>
#       <td>0.156250</td>
#       <td>0.129387</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.593750</td>
#       <td>0.615554</td>
#       <td>204.000000</td>
#       <td>163.000000</td>
#       <td>248.000000</td>
#       <td>0.000000</td>
#       <td>204.000000</td>
#       <td>163.000000</td>
#       <td>248.000000</td>
#       <td>0.000011</td>
#       <td>No Log</td>
#       <td>0.500000</td>
#       <td>0.925820</td>
#       <td>0.093750</td>
#       <td>0.129387</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.606166</td>
#       <td>214.250000</td>
#       <td>136.000000</td>
#       <td>331.000000</td>
#       <td>0.000000</td>
#       <td>214.250000</td>
#       <td>136.000000</td>
#       <td>331.000000</td>
#       <td>0.000009</td>
#       <td>No Log</td>
#       <td>0.500000</td>
#       <td>0.925820</td>
#       <td>0.125000</td>
#       <td>0.133631</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>1.406250</td>
#       <td>1.212019</td>
#       <td>164.375000</td>
#       <td>107.000000</td>
#       <td>194.000000</td>
#       <td>0.000000</td>
#       <td>164.375000</td>
#       <td>107.000000</td>
#       <td>194.000000</td>
#       <td>0.000006</td>
#       <td>No Log</td>
#       <td>1.250000</td>
#       <td>1.035098</td>
#       <td>0.156250</td>
#       <td>0.129387</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.812500</td>
#       <td>1.178054</td>
#       <td>296.125000</td>
#       <td>170.000000</td>
#       <td>768.000000</td>
#       <td>0.125000</td>
#       <td>228.714294</td>
#       <td>170.000000</td>
#       <td>290.000000</td>
#       <td>0.000009</td>
#       <td>No Log</td>
#       <td>0.750000</td>
#       <td>1.035098</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.906250</td>
#       <td>1.173675</td>
#       <td>239.750000</td>
#       <td>174.000000</td>
#       <td>342.000000</td>
#       <td>0.000000</td>
#       <td>239.750000</td>
#       <td>174.000000</td>
#       <td>342.000000</td>
#       <td>0.000006</td>
#       <td>No Log</td>
#       <td>0.750000</td>
#       <td>1.035098</td>
#       <td>0.156250</td>
#       <td>0.129387</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>1.086656</td>
#       <td>186.750000</td>
#       <td>132.000000</td>
#       <td>213.000000</td>
#       <td>0.000000</td>
#       <td>186.750000</td>
#       <td>132.000000</td>
#       <td>213.000000</td>
#       <td>0.000006</td>
#       <td>No Log</td>
#       <td>0.500000</td>
#       <td>0.925820</td>
#       <td>0.125000</td>
#       <td>0.133631</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>1.375000</td>
#       <td>1.111625</td>
#       <td>236.250000</td>
#       <td>191.000000</td>
#       <td>328.000000</td>
# [MATH HARD] Question: John has 20% more boxes than Jules. Jules has 5 more boxes t...
# Expected: Joseph has 100 * 0.80 = <<100*0.80=80>>80 less boxes than Stan.
# Joseph has a total of 100 - 80 = <<100-80=20>>20 boxes.
# Jules has 20 + 5 = <<20+5=25>>25 boxes.
# John has 25 * 0.20 = <<25*0.20=5>>5 more boxes than Jules.
# John has a total of 25 + 5 = <<25+5=30>>30 boxes
# #### 30 | Got: 7.5 | Reward: 0.0
#
# [MATH HARD] Question: There are one-third as many Ford trucks as Dodge trucks in t...
# Expected: If there are half as many VW Bugs as there are Toyota trucks in this parking lot, and there are 5 VW Bugs, then there are 2*5=<<2*5=10>>10 Toyota trucks in the parking lot.
# And if there are twice as many Ford trucks as Toyota trucks in this parking lot, then there are 2*10=<<2*10=20>>20 Ford trucks in the parking lot.
# And if there are one-third as many Ford trucks as Dodge trucks in the parking lot, then there are 20*3=<<20*3=60>>60 Dodge trucks in the parking lot of the Taco Castle.
# #### 60 | Got: <reasoning>
# Let's start by analyzing the given information:
# 1. There are half as many Volkswagon Bugs as there are Toyota trucks.
# 2. There are 5 Volkswagon Bugs in the parking lot.
# Since there are half as many Volkswagon Bugs as Toyota trucks, we can calculate the number of Toyota trucks as follows:
# Toyota trucks = 2 x Volkswagon Bugs
# = 2 x 5
# = 10
#
# 3. There are thrice as many Ford trucks as Toyota trucks.
# We will calculate the number of Ford trucks using the number of Toyota trucks:
# Ford trucks = 3 x Toyota trucks
# = 3 x 10
# = 30
#
# 4. There are one-third as many Ford trucks as Dodge trucks.
# We can express the relationship between Ford trucks and Dodge trucks as:
# Ford trucks = 1/3 x Dodge trucks
# We already calculated the number of Ford trucks.  Now we will solve for Dodge trucks using that value:
# 30 = 1/3 x Dodge trucks
# Multiplying both sides by 3:
# 90 = Dodge trucks
#
# The answer is 90. | Reward: 0.0
#
# [MATH HARD] Question: In a single day, it rained for many hours. From 2pm to 4pm, ...
# Expected: From 2pm to 4pm is 4-2=2 hours.
# Thus, from 2-4pm, raining at 4 inches per hour, it added 8 inches to the rain gauge.
# From 4pm to 7pm is 7-4=<<7-4=3>>3 hours.
# Thus, from 4-7pm, raining at a rate of 3 inches per hour, it added 3*3=<<3*3=9>>9 inches to the rain gauge.
# From 7pm to 9pm is 9-7=<<9-7=2>>2 hours.
# Thus, from 7-9pm, raining at a rate of 0.5 inches per hour, it added 2*0.5=1 inch to the gauge.
# If the gauge originally contained 2 inches of water, by 9pm the gauge contained 2+8+9+1=<<2+8+9+1=20>>20 inches of water.
# #### 20 | Got: Let's calculate the total amount of rain collected between 2pm and 9pm.
#
# From 2pm to 4pm, the rain rate is 4 inches per hour. Since it rained for 2 hours, the total rain collected during this time is:
# 4 inches/hour x 2 hours = 8 inches
#
# From 4pm to 7pm, the rain rate is 3 inches per hour. Since it rained for 3 hours, the total rain collected during this time is:
# 3 inches/hour x 3 hours = 9 inches
#
# From 7pm to 9pm, the rain rate is 0.5 inches per hour. Since it rained for 2 hours, the total rain collected during this time is:
# 0.5 inches/hour x 2 hours = 1 inch
#
# Now, let's add up the total rain collected during these three periods:
# 8 inches + 9 inches + 1 inch = 18 inches
#
# The rain gauge already contained 2 inches at 2pm. Adding the total rain collected between 2pm and 9pm, we get:
# 2 inches + 18 inches = 20 inches
#
# The final answer is: $\boxed{20}$ inches | Reward: 0.0
#
# [MATH HARD] Question: Graeme is weighing cookies to see how many he can fit in his...
# Expected: First find how many cookies are in a pound. 16 ounces per pound / 2 ounces/cookie = 8 cookies per pound
# The box can hold 40 pounds, so 40 pounds * 8 cookies per pound = <<40*8=320>>320 cookies.
# #### 320 | Got: 320 | Reward: 2.0
#
# [MATH HARD] Question: Cynthia has three children whose ages add up to 35. Matthew ...
# Expected: Let A be Matthew’s age.
# Rebecca is A - 2 years old.
# Freddy is A + 4 years old.
# Their ages add up to 35, so A + A - 2 + A + 4 = 3A + 2 = 35.
# Therefore, 3A = 35 - 2 = 33.
# Matthew is A = 33 / 3 = <<33/3=11>>11 years old.
# Thus, Freddy is 11 + 4 = <<11+4=15>>15 years old.
# #### 15 | Got: 11 | Reward: 0.0
#
# [MATH HARD] Question: Bob, a marathon runner, is preparing for a race.  He runs a ...
# Expected: Day 1: 70(.20)=<<70*.20=14>>14 miles
# 70-14=<<70-14=56>>56 miles remaining
# Day 2:56/2=<<56/2=28>>28 miles
# 56-28=<<56-28=28>>28 miles remaining
# #### 28 | Got: <reasoning>
# First, let's calculate the number of miles Bob ran on day one, which is 20% of 70 miles.
#
# 20% of 70 = (20/100) * 70
# = 0.2 * 70
# = 14 miles
#
# So, on day one, Bob ran 14 miles.
#
# Next, let's find the remaining miles that need to be covered after day one.
# Remaining miles = Total miles - Miles run on day one
# = 70 - 14
# = 56 miles
#
# Now, on day two, Bob runs 50% of the remaining miles.
#
# 50% of 56 = (50/100) * 56
# = 0.5 * 56
# = 28 miles
#
# So, on day two, Bob runs 28 miles.
#
# Now, let's calculate how many miles are left for day three to complete the 70 miles.
# Miles left for day three = Remaining miles - Miles run on day two
# = 56 - 28
# = 28 miles
#
# The final answer is: 28 | Reward: 0.0
#
# [MATH HARD] Question: Kate wants to buy a special pen as a gift for her friend. Th...
# Expected: Currently, Kate has only 1/3 * 30 = $<<1/3*30=10>>10.
# That means Kate needs 30 - 10 = $<<30-10=20>>20 more to buy the pen.
# #### 20 | Got: <math Problem: Kate has to save for a special pen that costs $30.
#
# Step 1: Calculate how much money Kate currently has.
# Since Kate has only money for a third of the amount of the pen, and the pen costs $30, Kate has
# $30 / 3 = $10.
#
# Step 2: Determine the additional amount needed to purchase the pen.
# Since Kate needs $30 to buy the pen, and she currently has $10, she needs
# $30 - $10 = $20 more.
#
# Answer: $20. | Reward: 0.0
#
# [MATH HARD] Question: James finds 3 bills in his pocket.  They are all 20s.  If he...
# Expected: He found 3*20=$<<3*20=60>>60
# So now he has 60+75=$<<60+75=135>>135
# #### 135 | Got: James has $135 now. | Reward: 2.0
#
# [MATH HARD] Question: Axel bought an aquarium that was marked down 50% from an ori...
# Expected: The aquarium was bought for $120 x 50/100 = $<<120*50/100=60>>60 less.
# So the marked down price of the aquarium was $120 - $60 = $<<120-60=60>>60.
# Axel paid $60 x 5/100 = $<<60*5/100=3>>3 additional for the sales tax.
# Therefore, the total cost of the aquarium was $60 + $3 = $<<60+3=63>>63.
# #### 63 | Got: $63 | Reward: 2.0
#
# [MATH HARD] Question: Tom bought 10 packages of miniature racing cars. Each packag...
# Expected: Tom had 10 x 5 = <<10*5=50>>50 miniature racing cars.
# Tom gave 50 x 1/5 = <<50*1/5=10>>10 miniature racing cars to each of his two nephews.
# So, he gave a total of 10 x 2 = <<10*2=20>>20 cars to his two nephews.
# Therefore, Tom is left with 50 - 20 = <<50-20=30>>30 miniature racing cars.
# #### 30 | Got: 30 | Reward: 2.0
#
# [MATH HARD] Question: A monkey swings from branch to branch at an average distance...
# Expected: If a monkey swings 1.2 meters a second then a monkey can swing 1.2 meters/second * 60 seconds/minute = <<1.2*60=72>>72 meters in a minute.
# If a monkey swings 72 meters in a minute then a monkey can swing 72 meters/min * 30 minutes = <<72*30=2160>>2,160 meters in 30 minutes
# #### 2160 | Got: <reasoning>
# To find the distance the monkey swings in 30 minutes, we need to follow these steps:
# 1. First, convert the given time from minutes to seconds because the speed is given in meters per second.
# 2. Then multiply the speed of swinging by time in seconds.
# </reasoning>
#
# We know:
# - Total time in seconds: 30 minutes * 60 seconds/minute = 1800 seconds
# - Distance per second = 1.2 meters/second
#
# Now, let's calculate the total distance:
# Total distance = Speed * Time
# Total distance = 1.2 meters/second * 1800 seconds
#
# Performing the multiplication:
# Total distance = 1.2 * 1800
# Total distance = 2160 meters | Reward: 0.0
#
# [MATH HARD] Question: The total number of whales in the sea this year is double wh...
# Expected: If there were 4000 whales in the sea three years ago, and their number doubled this year, then there are 2*4000 = <<4000*2=8000>>8000 whales in the sea this year.
# If the predictions come true, there will be 8000+800 = <<8000+800=8800>>8800 whales in the water next year.
# #### 8800 | Got: The total number of whales in the sea next year is 8800. | Reward: 2.0
#
# [MATH HARD] Question: Tommy is looking at his change collection. He has 10 more di...
# Expected: Tommy has 40 pennies because 10 x 4 = <<10*4=40>>40
# Tommy has 50 dimes because 40 + 10 = <<40+10=50>>50
# Tommy has 100 nickels because 50 x 2 = <<50*2=100>>100
# #### 100 | Got: The final answer is 100. | Reward: 2.0
#
# [MATH HARD] Question: Tracy, Michelle, and Kati take a road trip that is a total o...
# Expected: Let x represent the number of miles Kati drives
# Michelle:3x
# Tracy:20+2(3x)=20+6x
# Total:x+3x+20+6x=1000
# 10x+20=1000
# 10x=980
# x=<<98=98>>98 miles
# 3(98)=<<3*98=294>>294 miles
# #### 294 | Got: <reasoning>
# To solve this problem, we will start by defining variables for the miles driven by each person. Let:
# - M = miles driven by Michelle
# - T = miles driven by Tracy
# - K = miles driven by Kati
#
# According to the problem statement:
# - The total distance is 1000 miles, so the sum of the miles driven by each driver is 1000.
# - Tracy drives 20 miles more than twice the miles driven by Michelle, so T = 2M + 20
# - Michelle drives 3 times the amount that Kati drives, so M = 3K
# We can now write the equation to represent the total distance driven by all three drivers:
# T + M + K = 1000
#
# Substitute the equation T = 2M + 20 and the equation M = 3K into the total equation:
# (2M + 20) + M + K = 1000
#
# Simplify the equation to put all the variables on one side:
# 3M + K + 20 = 1000
#
# Combine the constants on the right-hand side:
# 3M + K = 980
#
# Now substitute the equation M = 3K:
# 3(3K) + K = 980
# Expanding 3(3K) to 9K
# 9K + K = 980
# Combine like terms:
# 10K = 980
#
# Divide both sides by 10:
# K = 98
#
# Now that we have the value of K, replace K in the equation M = 3K
# M = 3 * 98
# M = 294
#
# The final answer is: 294 | Reward: 0.0
#
# [MATH HARD] Question: Claire is scheduling her day. She has four hours to clean an...
# Expected: We know Claire has spent a total of 24 hours in a day - 4 hours cleaning - 2 hours cooking - 8 hours sleeping = 10 hours crafting and tailoring.
# Since she split her time equally, she must have spent 10 hours * 0.5 = <<10*0.5=5>>5 hours crafting.
# #### 5 | Got: 5 | Reward: 2.0
#
# [MATH HARD] Question: John climbs 3 staircases.  The first staircase has 20 steps....
# Expected: The second flight had 20*2=<<20*2=40>>40 steps
# The third had 40-10=<<40-10=30>>30 steps
# So in total, he climbed 20+40+30=<<20+40+30=90>>90 steps
# So he climbed 90*.5=<<90*.5=45>>45 feet
# #### 45 | Got: To solve this problem, let's break it down step by step.
#
# Step 1: Find the number of steps in the first staircase.
# The first staircase has 20 steps.
#
# Step 2: Find the number of steps in the second staircase.
# The second staircase has twice as many steps as the first, so it has 2 x 20 = 40 steps.
#
# Step 3: Find the number of steps in the final staircase.
# The final staircase has 10 fewer steps than the second one, so it has 40 - 10 = 30 steps.
#
# Step 4: Calculate the total number of steps.
# The total number of steps is 20 + 40 + 30 = 90 steps.
#
# Step 5: Convert the total number of steps to feet.
# Each step is 0.5 feet, so the total distance is 90 steps x 0.5 feet/step = 45 feet.
#
# The final answer is: $\boxed{45}$ | Reward: 0.0
#
# [MATH HARD] Question: Maiya has two sisters. The first sister is twice as old as M...
# Expected: Their total age is 15 because 3 x 5 = <<3*5=15>>15
# 15 - X - 2X -(X-1) is equivalent to 16 = 4X
# Maiya is 4 years old because 16 / 4 = <<16/4=4>>4
# #### 4 | Got: 4 | Reward: 2.0
#
# [MATH HARD] Question: James needs 40 fish to make one sushi roll. He goes to the m...
# Expected: If James bought 400 fish, the number of fish that were bad is 20/100*400 = <<20/100*400=80>>80
# The remaining fish that he used to make the sushi rolls is 400-80 = <<400-80=320>>320
# If 40 fish are required to make one sushi roll, 320 fish will make 320/40 = <<320/40=8>>8 sushi rolls
# #### 8 | Got: 8 | Reward: 2.0
#
# [MATH HARD] Question: John is an eccentric millionaire.  He decides to fill his sw...
# Expected: The pool is 10*6*20=<<10*6*20=1200>>1200 cubic feet
# That means it is 25*1200=<<25*1200=30000>>30000 liters
# So it cost 3*30,000=$<<3*30000=90000>>90,000
# #### 90000 | Got: <reasoning>
# To solve this problem, we need to find the volume of the pool and then multiply it by the number of liters needed to fill the pool, and finally multiply the total number of liters by the cost per liter.
#
# First, we need to find the volume of the pool. The pool is a rectangular prism (long, thin shape), so we need to multiply its length, width, and height.
#
# The formula for the volume of a rectangular prism is V = length × width × height
#
# V = 20 ft × 6 ft × 10 ft
# V = 1200 cubic feet
#
# Since a cubic foot of water is 25 liters, we can multiply the volume by 25 to find the total number of liters needed to fill the pool.
#
# Total liters = 1200 cubic feet × 25 liters/cubic foot
# Total liters = 30000 liters
#
# Now, we can multiply the total number of liters by the cost per liter to find the total cost.
#
# Total cost = 30000 liters × $3 liter
# Total cost = $90000 | Reward: 0.0
#
# [MATH HARD] Question: Mark and Peter dug ponds in their backyards. Mark’s pond is ...
# Expected: Let’s use p for the number of feet in Mark’s pond
# 3*p+4=19
# 3*p=19-4=15
# 3p=15
# p=<<5=5>>5
# #### 5 | Got: <reasoning>
# Let's start by defining the unknown:
# Let x be the depth of Peter's pond.
#
# We know that Mark's pond is 4 feet deeper than 3 times Peter's pond. So, we can write an equation:
#
# Mark's pond depth = 3(x) + 4
#
# Since Mark's pond is 19 feet deep, we can set up the equation:
#
# 3(x) + 4 = 19
#
# Now, we can solve for x.
#
# First, subtract 4 from both sides of the equation:
#
# 3(x) = 19 - 4
# 3(x) = 15
#
# Next, divide both sides of the equation by 3:
#
# x = 15 ÷ 3
# x = 5
#
# So, Peter's pond is 5 feet deep.
#
# The final answer is:
#
# 5 | Reward: 0.0
#
# [MATH HARD] Question: Wes wants to place a large planter pot at each corner of his...
# Expected: Each pot will have 4 creeping jennies that cost $4.00 each so that's 4*4 = $<<4*4=16.00>>16.00
# Each pot will have 4 geraniums that are $3.50 each so that's 4*3.50 = $<<4*3.50=14.00>>14.00 each
# The fern is $15.00, the creeping jennies are $16.00 and the geraniums are $14.00 for a total of 15+16+14 = $<<15+16+14=45.00>>45.00 per pot
# He wants a planter at each corner of his rectangle pool. A rectangle has 4 corners so he needs 4 pots at $45.00 per pot for a total of 4*45 = $<<4*45=180.00>>180.00
# #### 180 | Got: $90.00 | Reward: 0.0
#
# [MATH HARD] Question: Nick is asking all his co-workers to chip in for a birthday ...
# Expected: First find Todd's contribution by doubling the boss's contribution: $15 * 2 = $<<15*2=30>>30
# Now subtract Todd and the boss's contributions to find out how much still needs to be paid: $100 - $30 - $15 = $<<100-30-15=55>>55
# Now divide the remaining cost by the number of employees to find the cost per employee: $55 / 5 employees = $<<55/5=11>>11/employee
# #### 11 | Got: $11 | Reward: 2.0
#
# [MATH HARD] Question: Quentin, Skylar, and Colten have a total of 383 chickens.  Q...
# Expected: Let x represent the number of chickens that Colten has
# Skylar:3x-4
# Quentin: 25+2(3x-4)=25+6x-8=6x+17
# Total:x+3x-4+(6x+17)=383
# 10x+13=383
# 10x=370
# x=<<37=37>>37 chickens
# #### 37 | Got: The final answer is 36.5. | Reward: 0.0
#
# [MATH HARD] Question: A club with 30 members ordered fruit juices. Two-fifths of t...
# Expected: 30 x 2/5 = <<30*2/5=12>>12 members ordered lemon juice.
# So, 30 - 12 = <<30-12=18>>18 members did not order lemon juice.
# Since 1/3 of the remaining ordered mango juice, then 18 x 2/3 = <<18*2/3=12>>12 members ordered mango juice.
# Therefore, 18 - 12 = <<18-12=6>>6 members ordered orange juice.
# #### 6 | Got: <reasoning>
# To solve this problem, we need to break it down step by step.
#
# 1. Calculate the number of members who ordered lemon juice:
#    Total number of members = 30
#    Members who ordered lemon juice = (2/5) * 30
#    = 2/5 * (30/1)
#    = 2/1 * 30
#    = 2 * 30
#    = 60/1
#    = 12
#
# So, 12 members ordered lemon juice.
#
# 2. Now, we need to calculate the number of members who have not ordered lemon juice yet.
#    Remaining members = Total members - members who ordered lemon juice
#    = 30 - 12
#    = 30 - 12
#    = 18
#
# 3. Now, we want to calculate the number of members who ordered mango juice.
#    Members who ordered mango juice = (1/3) * remaining members
#    = (1/3) * 18
#    = 1/3 * (18/1)
#    = 1/1 * 18
#    = 1 * 18
#    = 18/1
#
# So, 18 members ordered mango juice.
#
# 4. Now we can calculate the number of members who ordered orange juice.
#    Members who ordered orange juice = Remaining members - members who ordered mango juice
#    = 18 - 18
#    = 0/1
#
# So, 0 members ordered orange juice.
#
# The final answer is 0. | Reward: 0.0
#
# [MATH HARD] Question: Carla bought 2 bags of mini peanut butter cups on clearance....
# Expected: Each bag was $6.00 but was marked down 75% for clearance so that's 6*.75 = $<<6*.75=4.50>>4.50 discount
# Each bag was $6.00 and there is a $4.50 discount so each bag is 6-4.50 = $<<6-4.50=1.50>>1.50
# Each bag was marked down to $1.50 a bag and she bought 2 bags for a total of 1.5*2 = $<<1.5*2=3.00>>3.00
# #### 3 | Got: $3.00 | Reward: 2.0
#
# [MATH HARD] Question: Chalktown High School had their prom last weekend. There wer...
# Expected: There were 123 students – 3 single attendees = <<123-3=120>>120 students in couples.
# 120 students / 2 in a couple = <<120/2=60>>60 couples.
# #### 60 | Got: 60 | Reward: 2.0
#
# [MATH HARD] Question: In soccer, players receive yellow cards when they are cautio...
# Expected: In coach Tim's team, 5 out of 11 players did not receive any caution, so 11 - 5 = <<11-5=6>>6 players were cautioned.
# Each cautioned player received a yellow card, so all the cautioned players received 6 * 1 =<<6*1=6>>6 yellow cards.
# Knowing that each red card corresponds to 2 yellow cards, the team would have 6 / 2 = <<6/2=3>>3 red cards.
# #### 3 | Got: 3 | Reward: 2.0
#
# [MATH HARD] Question: Fabian has three times more marbles than Kyle and five times...
# Expected: Kyle has a third of Fabian's number of marbles, so he has 15 / 3 = <<15/3=5>>5 marbles.
# Miles has a fifth of Fabian's number of marbles, so he has 15 / 5 = <<15/5=3>>3 marbles.
# Miles and Kyle together have 5 + 3 = <<5+3=8>>8 marbles.
# #### 8 | Got: 8 | Reward: 2.0
#
# [MATH HARD] Question: John buys 30 ducks for $10 each.  They weigh 4 pounds and he...
# Expected: He bought the ducks for 30*10=$<<30*10=300>>300
# He sold each duck for 4*5=$<<4*5=20>>20
# So he sold all the ducks for 30*20=$<<30*20=600>>600
# So he made a profit of 600-300=$<<600-300=300>>300
# #### 300 | Got: $300 | Reward: 2.0
#
# [MATH HARD] Question: Francis and Kiera had breakfast at a cafe. Muffins cost $2 e...
# Expected: Francis bought 2 × $2 = $<<2*2=4>>4 worth of muffins.
# Francis bought 2 × $3 = $<<2*3=6>>6 worth of fruit cups.
# Kiera bought 2 × $2 = $<<2*2=4>>4 worth of muffins.
# Kiera bought 1 × $3 = $<<1*3=3>>3 worth of fruit cups.
# Their breakfast cost $4 + $6 + $4 + $3 = $<<4+6+4+3=17>>17 in total.
# #### 17 | Got: Let's break down the problem step by step.
#
# Francis had 2 muffins and 2 fruit cups. The cost of muffins for Francis is 2 * $2 = $4.
#
# Francis also had 2 fruit cups, so the cost of the fruit cups is 2 * $3 = $6.
#
# To find the total cost of their breakfast for Francis, we add the cost of muffins and fruit cups together: $4 + $6 = $10.
#
# Kiera had 2 muffins and 1 fruit cup. The cost of muffins for Kiera is 2 * $2 = $4.
#
# Kiera also had 1 fruit cup, so the cost of the fruit cup is 1 * $3 = $3.
#
# To find the total cost of their breakfast for Kiera, we add the cost of muffins and fruit cups together: $4 + $3 = $7.
#
# Now, we add the total cost of their breakfast together: $10 (Francis') + $7 (Kiera's) = $17.
#
# The final answer is: $17 | Reward: 0.0
#
# [MATH HARD] Question: Two-fifths of the seats in an auditorium that holds 500 peop...
# Expected: 500/ 2/5 = 200 seats are already taken.
# 500/ 1/10 = <<500/1/10=50>>50 seats are broken.
# So 200 + 50 = <<200+50=250>>250 seats are either taken or broken.
# Therefore, 500 - 250 = <<500-250=250>>250 seats are still available.
# #### 250 | Got: <reasoning>
# To find the number of seats currently taken, we need to calculate 2/5 of 500.
#
# 2/5 x 500 =
# First, multiply the numerator by 500.
# 2 x 500 = 1000
#
# Then, divide by 5.
# 1000 ÷ 5 = 200
#
# So, there are 200 seats taken.
#
# Next, we need to find the total number of broken seats. We know that 1/10 of the seats are broken.
#
# 1/10 x 500 =
# First, multiply the numerator by 500.
# 1 x 500 = 500
#
# Then, divide by 10.
# 500 ÷ 10 = 50
#
# So, there are 50 seats that are broken.
#
# Now, we know that 200 seats are taken and 50 are broken, so we can calculate the number of available seats.
#
# Total seats = 500
# Total taken and broken seats = 200 + 50 = 250
# Seats available = Total seats - Total taken and broken seats
# Seats available = 500 - 250
# Seats available = 250
#
# So, the final answer is 250. | Reward: 0.0
#
# [MATH HARD] Question: Hannah hangs a 2 foot by 4 foot painting on a 5 foot by 10 f...
# Expected: First find the area of the painting: 2 feet * 4 feet = <<2*4=8>>8 square feet
# Then find the area of the wall: 5 feet * 10 feet = <<5*10=50>>50 square feet
# Then divide the area of the painting by the area of the wall and multiply by 100% to express the answer as a percentage: 8 square feet / 50 square feet * 100% = 16%
# #### 16 | Got: To find the percentage of the wall taken up by the painting, we need to calculate the area of the painting and the area of the wall, then divide the area of the painting by the area of the wall, and express it as a percentage.
#
# Step 1: Calculate the area of the painting
#
# The painting is 2 feet by 4 feet, so the area of the painting is:
# Area = length * width
# = 2 * 4
# = 8 square feet
#
# Step 2: Calculate the area of the wall
#
# The wall is 5 feet by 10 feet, so the area of the wall is:
# Area = length * width
# = 10 * 5
# = 50 square feet
#
# Step 3: Calculate the ratio of the paintning area to the wall area
#
# Ratio = (Area of painting) / (Area of wall)
# = 8 / 50
# = 0.16
#
# Step 4: Convert the ratio to a percentage
#
# Percentage = (Ratio * 100)
# = (0.16 * 100)
# = 16%
#
# Therefore, the painting takes up 16% of the wall. | Reward: 0.0
#
# [MATH HARD] Question: A cleaning company produces two sanitizer sprays. One spray ...
# Expected: After the first spray kills 50% of germs, there will be 100 - 50 = <<100-50=50>>50% left.
# The second spray kills 25%, but 5% have already been killed by the 50% spray, so it kills 25 - 5 = <<25-5=20>>20%.
# After the second spray kills 20% of the remaining germs, there will be 50 - 20 = <<50-20=30>>30% left.
# #### 30 | Got: The final numerical answer is: 62.5 | Reward: 0.0
#
# [MATH HARD] Question: Betty’s herb garden has 2 more than twice as many oregano pl...
# Expected: Two more than twice as many oregano plants as basil translates to 2 + 2*5 = <<2+2*5=12>>12 oregano plants
# All together, Betty’s herb garden has 12 + 5 = <<12+5=17>>17 plants.
# #### 17 | Got: 17 | Reward: 2.0
#
# [MATH HARD] Question: A factory manufactures cars with 5 doors. The factory was pl...
# Expected: The factory due to shortages will produce 200 - 50 = <<200-50=150>>150 cars.
# Due to the pandemic, they will now produce 150 / 2 = <<150/2=75>>75 cars.
# The company will have to manufacture 75 * 5 = <<75*5=375>>375 doors.
# #### 375 | Got: 375 | Reward: 2.0
#
# [MATH HARD] Question: Alice is planting bushes around three sides of her yard. If ...
# Expected: First find the total distance the bushes need to cover: 16 feet/side * 3 sides = <<16*3=48>>48 feet
# Then divide the total distance to fill by the distance each bush fills to find the number of bushes Alice needs to buy: 48 feet / 4 feet/bush = <<48/4=12>>12 bushes
# #### 12 | Got: 12 | Reward: 2.0
#
# [MATH HARD] Question: Lisa walks 10 meters each minute. Every day, she walks for a...
# Expected: Since there are 60 minutes in 1 hour, then Lisa walks for 1 x 60 = <<60=60>>60 minutes every day.
# For 60 minutes, Lisa walks 60 x 10 = <<60*10=600>>600 meters.
# Thus, she walks for 600 x 2 = <<600*2=1200>>1200 meters in two days.
# #### 1200 | Got: 1200 | Reward: 2.0
#
# [MATH HARD] Question: Every day, while going to school, Shane drives a total of 10...
# Expected: To go to school and back, Shane drives 2*10 = <<2*10=20>>20 miles per day.
# In 80 days of a semester, he drives for 80*20 = <<80*20=1600>>1600 miles
# #### 1600 | Got: 1600 | Reward: 2.0
#
# [MATH HARD] Question: If the price of a bag of cherries is $5 when the price of a ...
# Expected: At a 10 percent discount, Jordyn will pay 10/100%*$5=$.50 less for a bag of cherries.
# To buy one of the cherries at a 10% discount Jordyn will pay $5-$0.50=$<<5-0.5=4.50>>4.50
# The cost of buying 50 bags of cherries at the 10% discount is 50*4.50=$<<50*4.50=225>>225
# Also, at a 10% discount, Jordyn will pay 10/100*$7=$<<10/100*7=0.70>>0.70 less for a bag of olives.
# The price of a bag of olives at a 10% discount is $7-$0.70=$<<7-0.7=6.3>>6.3
# To buy 50 bags of olives Jordyn will pay $6.3*50=$<<6.3*50=315>>315
# The total cost of buying 50 bags of each fruit at a 10% discount is $315+$225=$540
# #### 540 | Got: $540 | Reward: 2.0
#
# [MATH HARD] Question: Adam has three more than twice as many tattoos as Jason has....
# Expected: 2 tattoos on each arm is a total of 2*2=<<2*2=4>>4 tattoos.
# 3 tattoos on each leg is a total of 2*3=<<2*3=6>>6 tattoos.
# Thus, Jason has 4+6=<<4+6=10>>10 tattoos.
# Twice the number of tattoos that Jason has is 2*10=<<2*10=20>>20 tattoos.
# Adam has 3 more than twice the number Jason has, or 3+20=<<3+20=23>>23 tattoos.
# #### 23 | Got: 23 | Reward: 2.0
#
# [MATH HARD] Question: The total average age of three friends is 40. Jared is ten y...
# Expected: The total age for the three friends is 40*3 = <<40*3=120>>120
# If Molly's age is 30, then Jared and Hakimi have a total age of 120-30 = 90.
# Let's say the age of Hakimi is x.
# Since Jared is 10 years older than Hakimi, Jared is x+10 years old.
# Jared and Hakimi's total age is x+(x+10) = 90
# This translates to 2x=90-10
# 2x=80
# Hakimi's age is x=80/2
# This gives us x=<<40=40>>40, which is Hamkimi's age.
# #### 40 | Got: <reasoning>
#
# To find the total age of all three friends, we need to multiply the average age by the number of friends.
#
# The average age of three friends is 40, and there are three friends.
# Total age = Average age * Number of friends
# Total age = 40 * 3
# Total age = 120
#
# Jared's age is ten years older than Hakimi, and Molly's age is 30.
# Let's assume the age of Hakimi is x. Then Jared's age would be x + 10, and Molly's age is 30.
#
# The sum of their ages is equal to the total age.
# So, we can write the equation as:
# x + (x + 10) + 30 = 120
#
# Combine like terms:
# 2x + 40 = 120
#
# Subtract 40 from both sides:
# 2x = 80
#
# Divide both sides by 2:
# x = 40
#
# Hakimi's age is 40. | Reward: 2.0
#
# [MATH HARD] Question: Sue works in a factory and every 30 minutes, a machine she o...
# Expected: Since there are 2 sets of 30 minutes in an hour, then in 8 hours there are 8 x 2 = <<8*2=16>>16 sets of 30 minutes.
# Hence, a machine that Sue oversees can produce 30 cans x 16 = <<30*16=480>>480 cans of soda in 8 hours.
# #### 480 | Got: 480 | Reward: 2.0
#
# [MATH HARD] Question: There are 88 dogs in a park. 12 of the dogs are running. Hal...
# Expected: 88/2 = <<88/2=44>>44 dogs are playing with toys.
# 88/4 = <<88/4=22>>22 dogs are barking.
# 88-12-44-22 = <<88-12-44-22=10>>10 dogs are not doing anything.
# #### 10 | Got: 66 | Reward: 0.0
#
# [MATH HARD] Question: Nancy has a bag containing 22 tortilla chips. She gives 7 to...
# Expected: She gave away 7+5=<<7+5=12>>12 chips.
# Then she kept 22-12=<<22-12=10>>10.
# #### 10 | Got: 10 | Reward: 2.0
#
# [MATH HARD] Question: Mica went to the grocery store and bought 2 kilograms of pas...
# Expected: Two kilograms of pasta cost $1.5 x 2 = $<<1.5*2=3>>3.
# One-fourth kilogram of ground beef cost $8 x 1/4 = $<<8*1/4=2>>2.
# Two jars of pasta sauce cost $2 x 2 = $<<2*2=4>>4.
# The total cost for the pasta, beef, and sauce is $3 + $2 + $4 = $<<3+2+4=9>>9.
# Since Mica also wants to buy Quesadilla, she should have $9 + $6 = $<<9+6=15>>15.
# #### 15 | Got: <reasoning>
# To find out how much money Mica should have with her, we need to calculate the total cost of the items she wants to buy.
#
# 1. 2 kilograms of pasta: costs $1.5 per kilogram, so 2 kg costs 2 * $1.5 = $3.
# 2. 1/4 kilogram of ground beef: costs $8 per kilogram, so 1/4 kg costs (1/4) * $8 = $2.
# 3. 2 jars of pasta sauce: costs $2 per jar, so 2 jars cost 2 * $2 = $4.
# 4. 1 Quesadilla: costs $6.
#
# Now we can add up all the money: $3 (pasta) + $2 (beef) + $4 (pasta sauce) + $6 (Quesadilla) =?
#
# 5. $3 + $2 = $5
# 6. $5 + $4 = $9
# 7. $9 + $6 = $15
#
# <Micahans to have$15 | Reward: 0.0
#
# [MATH HARD] Question: If there are four times as many apples as oranges in a certa...
# Expected: If there are four times as many apples as oranges in a certain fruit basket, with the number of apples being 15, there are 15*4=<<15*4=60>>60 oranges in the basket.
# If Emiliano eats 2/3 of the oranges in the basket, he would have taken 2/3*60=<<2/3*60=40>>40 oranges from the basket.
# With the number of apples in the basket being 15, if Emiliano eats 2/3 of them, 2/3*15=<<15*2/3=10>>10 apples would have been eaten by Emiliano.
# The total number of fruits eaten by Emiliano will total 10+40=<<10+40=50>>50
# #### 50 | Got: 12.5 | Reward: 0.0
#
# [MATH HARD] Question: John has a raw squat of 600 pounds without sleeves or wraps....
# Expected: Wraps add 600*.25=<<600*.25=150>>150 pounds to his lift
# So they add 150-30=<<150-30=120>>120 pounds more than sleeves
# #### 120 | Got: To find out how much more pounds John gets out of wraps versus sleeves, we need to find out how much more pounds wraps add than sleeves.
#
# Wraps add 25% to his squat.
# 25% of his squat (600) is:
# 600 x (25/100) = 600 x 0.25 = 150 pounds
#
# So, wraps add 150 pounds to his raw squat.
#
# Sleeves add 30 pounds.
#
# Now, we subtract the amount sleeves add to the amount wraps add to get a net gain for the wraps:
# 150 - 30 = 120
#
# The wraps gain 120 more pounds than sleeves.
#
# However, the question asks how much more pounds he gets out of wraps versus sleeves, so we don't need to find a net gain but rather just the difference.
#
# So, the wraps gain 120 - 30 = 90 more pounds compared to sleeves. | Reward: 0.0
#
# [MATH HARD] Question: Kennedy’s car can drive 19 miles per gallon of gas. She was ...
# Expected: Kennedy drove 15 + 6 + 2 + 4 + 11 = <<15+6+2+4+11=38>>38 miles.
# She gets 19 miles per gallon of gas, so she started with 38 / 19 = <<38/19=2>>2 gallons of gas.
# #### 2 | Got: Total gallons = 38 miles / 19 miles per gallon = 2 gallons | Reward: 0.0
#
# [MATH HARD] Question: Gary bought his first used car for $6,000.  Gary borrowed th...
# Expected: A full year has 12 months. So 2 years is 2*12 = <<2*12=24>>24 months
# The loan amount is $6,000 that he will repay in 24 months so 6000/24 = $<<6000/24=250>>250 per month
# If he paid his dad back in 5 years that 5*12 = <<5*12=60>>60 months
# $6,000 loan spread out over 60 months is 6000/60 = $<<6000/60=100>>100 per month
# To pay it off in 2 years instead of 5, Gary is paying 250-100 = $<<250-100=150>>150 more per month
# #### 150 | Got: <reasoning>
# To find out how much more Gary is spending per month to pay the loan back in 2 years instead of 5, we need to first calculate the monthly payments for each scenario.
#
# Let's start by calculating the monthly payment if Gary paid off the loan in 5 years. We can do this by dividing the total amount ($6,000) by the number of months in 5 years (120 months).
#
# Monthly payment (5 years): $6,000 / 120 months = $50 per month
#
# Now, let's calculate the monthly payment if Gary paid off the loan in 2 years (24 months).
#
# Monthly payment (2 years): $6,000 / 24 months = $250 per month
#
# Now that we have the monthly payments for each scenario, we can find the difference by subtracting the monthly payment for 5 years from the monthly payment for 2 years.
#
# Monthly payment difference: $250 (2 years) - $50 (5 years) = $200
#
# However, since Gary wants to know how much more he is spending per month, the answer is $200. | Reward: 0.0
#
# [MATH HARD] Question: The pet shop grooms dogs.  It takes 30 minutes to groom a po...
# Expected: At a rate of 30 minutes per poodle, 3 poodles will take 3*30=<<3*30=90>>90 minutes.
# If it takes half as much time to groom a terrier as it takes to groom a poodle, it takes 30/2=<<30/2=15>>15 minutes per terrier.
# At a rate of 15 minutes per terrier, 8 terriers will take 120 minutes.
# Thus, in total, it will take the pet shop 90+120=<<90+120=210>>210 minutes to groom 3 poodles and 8 terriers.
# #### 210 | Got: 210 | Reward: 2.0
#
# [MATH HARD] Question: Ellie went to visit a circus with Sarah and they both got lo...
# Expected: In the rooms with tall mirrors, Sarah saw her reflection a total of 10 reflections * 3 passes = <<10*3=30>>30 times.
# In the rooms with wide mirrors, Sarah saw her reflection a total of 5 reflections * 5 passes = <<5*5=25>>25 reflections.
# So Sarah saw her reflection a total of 30 + 25 = <<30+25=55>>55 times.
# In the rooms with tall mirrors, Ellie saw her reflection a total of 6 reflections * 3 passes = <<6*3=18>>18 times.
# In the rooms with wide mirrors, Ellie saw her reflection a total of 3 reflections * 5 passes = <<3*5=15>>15 times.
# So Ellie saw her reflection a total of 18 + 15 = <<18+15=33>>33 times.
# Therefore, Sarah and Ellie saw their reflections a total of 55 + 33 = <<55+33=88>>88 times.
# #### 88 | Got: 88 | Reward: 2.0
#
# [MATH HARD] Question: Liz's basketball team is down by 20 points in the final quar...
# Expected: Each free throw counts as 1 point, so 5 successful free throws means she scores 5*1= <<5*1=5>>5 points
# Each 3 pointer counts as 3 points, so this means Liz scores 3*3= <<3*3=9>>9 points from 3 pointers
# Each jump shot counts as 2 points, meaning Liz scores 4*2=<<4*2=8>>8 points of jump shots.
# Liz's opponents score 10 points during the quarter, meaning their lead is 30 points in total before accounting for Liz's scoring.
# Liz scores a total of 5+9+8=<<5+9+8=22>>22 points in the quarter.
# This amount is subtracted from the lead of Liz's opponents, meaning they win by 30-22= <<30-22=8>>8 points.
# #### 8 | Got: <reasoning>
# Let's start by identifying the number of points Liz scores in the final quarter:
#
# 1. 5 free throw shots: 5 x 1 point = 5 points
# 2. 3 three-pointers: 3 x 3 points = 9 points
# 3. 4 other jump shots: 4 x 2 points = 8 points
#
# The total number of points Liz scores is: 5 + 9 + 8 = 22 points
#
# The other team scores 10 points, but none of Liz's teammates score. So, the total points scored is 22 (Liz) + 10 (other team) = 32 points.
#
# Since the team was initially down by 20 points, and then Liz scores 22 points, we need to find the difference between the total points scored and the initial deficit.
#
# Net points scored: 32 - 20 = 12 points
#
# However, this is not the correct answer because Liz's team would win the game by 12 points, but we are asked to find out how much they lost by.
#
# Liz's initial deficit was -20 points; the actual deficit is -(-20) + 12 = 32 - 20 = 12 points, but this is the amount that Liz scored.  So Liz's team got wiped out by 12 points after the quarter | Reward: 0.0
#
# [MATH HARD] Question: Five dozens of people are attending your family reunion. You...
# Expected: Five dozens of people is equal to 5 x 12 = <<5*12=60>>60.
# 60 x 2 = <<60*2=120>>120 cans of soda are needed.
# So, this means 120/10 = <<120/10=12>>12 boxes of soda must be purchased.
# Thus, it will amount to $2 x 12 = $<<24=24>>24.
# Therefore, each family member will pay $24/6 = $<<24/6=4>>4.
# #### 4 | Got: $4 | Reward: 2.0
#
# [MATH HARD] Question: The town of Belize has 400 homes. One fourth of the town's h...
# Expected: There are 400/4 = <<400/4=100>>100 white homes in Belize.
# There are 400-100 = <<400-100=300>>300 non-white homes in Belize.
# There are 300/5 = <<300/5=60>>60 non-white homes that have a fireplace.
# There are 300-60 = <<300-60=240>>240 non-white homes that do not have a fireplace.
# #### 240 | Got: 240 | Reward: 2.0
#
# [MATH HARD] Question: John plants a plot of 3 trees by 4 trees.  Each tree gives 5...
# Expected: He has 3*4=<<3*4=12>>12 trees
# So he has 12*5=<<12*5=60>>60 apples
# So he sells the apples for 60*.5=$<<60*.5=30>>30
# #### 30 | Got: The final answer is: $30 | Reward: 2.0
#
# [MATH HARD] Question: Rodney is a door-to-door salesman trying to sell home securi...
# Expected: Let S be the number of systems Rodney sold on the first street.
# He sold 2S systems on the second street.
# Based on his commission, he sold 175 / 25 = <<175/25=7>>7 systems.
# In all, he sold S + 2S + 0 + 1 = 3S + 1 = 7 systems.
# On the first and second streets, he sold 3S = 7 - 1 = 6 systems.
# Thus, on the first street he sold S = 6 / 3 = <<6/3=2>>2 systems.
# On the second street, Rodney sold 2 * 2 = <<2*2=4>>4 security systems.
# #### 4 | Got: Let's break down the problem step by step.
#
#
# 1. Rodney gets a commission of $25 for each security system he sells.
# 2. Let's represent the number of sales on the second street as x.
# 3. Since the first street gave him half the sales that the second street did, he made x/2 sales on the first street.
# 4. He made 1 sale on the fourth street.
#
# The total commission he received is:
# x/2 + x + 1 = total sales
# 5. Multiply both sides by 2 to get rid of fractions:
# x + 2x + 2 = total sales * 2
# = 3x + 2 = total sales
#
#
# Now, multiply the total sales by his commission to get the total commission:
# 3x + 2 * 25
#     = 3x + 50 = 175
#    Substract 50 from both sides: 3x = 125
#    Divide both sides by 3: x = 41.66666667
# We will round down to 41 since no one can sell a fraction of a system
#
#
# Rodney made 41 sales on the second street | Reward: 0.0
#
# [MATH HARD] Question: The county fair was hosting a pumpkin contest to see who cou...
# Expected: Jessica's pumpkin weighs half the weight of Brad's 54-pound pumpkin so 54/2 = <<54/2=27>>27 pounds
# Betty's pumpkin weighs 4 times the amount of Jessica's 27-pound pumpkin so it weighs 4*27 = <<4*27=108>>108
# Betty has the heaviest pumpkin at 108 pounds while Jessica's is the lowest at 27 pounds so the difference is 108-27 =<<108-27=81>>81 pounds
# #### 81 | Got: 81 | Reward: 2.0
#
# [MATH HARD] Question: Tom fills a 250 pound sandbag 80% full.  But the filling mat...
# Expected: The bag full of sand would weigh 250 * .8 = <<250*.8=200>>200 pounds
# The filling material would make it 200 * .4 = <<200*.4=80>>80 pounds heavier
# So it weighs 200 + 80 = <<200+80=280>>280 pounds
# #### 280 | Got: <step1>
# To find the weight of the filling material Tom is using (40% heavier than sand), first we need to find the weight of sand that would fill the bag.
# </step1>
# <step2>
# We need to calculate 80% of the bag's original capacity, which is 250 pounds.
# 80% of 250 = 0.8 * 250 = 200 pounds
# This is the weight of the sand that the bag can hold (if it were completely full of sand).
# </step2>
# <step3>
# Since the filling material is 40% heavier than sand, we need to add 40% of 200 pounds (the weight of the sand it can hold) to the actual weight of sand to find the weight of the filling material.
# ...
# #### 6 | Got: $19 | Reward: 0.0
#
# [MATH HARD] Question: Zilla spent 7% of her monthly earnings on rent, half of it o...
# Expected: Since $133 is equal to 7% of her earnings, then 1% is equal to $133/7 = $<<133/7=19>>19.
# The total monthly earning of Zilla is represented by 100%, so $19 x 100 = $<<19*100=1900>>1900 is her monthly earnings.
# So, $1900/2 = $<<1900/2=950>>950 is spent on her other monthly expenses.
# The total amount spent on the rent and other monthly expenses is $133 + $950 = $<<133+950=1083>>1083.
# Hence, she saves $1900 - $1083 = $<<1900-1083=817>>817 per month.
# #### 817 | Got: 817 | Reward: 2.0
#
# [MATH HARD] Question: Kris has been suspended for bullying many times.  For every ...
# Expected: Three times as many days as a typical person has fingers and toes is 3*20=<<3*20=60>>60 days
# Three days per instance of bullying is 60/3=<<60/3=20>>20 instances of bullying.
# #### 20 | Got: <reasoning>
# Let's start by finding out how many fingers and toes a typical person has.
# A person has 10 fingers and 10 toes, so total, that is 20.
# Since Kris's suspensions are three times as many days as the number of fingers and toes a typical person has, her suspensions lasted 3 * 20 = 60 days in total.
#
# Now, since each suspension lasts for 3 days, we can calculate the number of suspensions by dividing the total number of days by 3.
# Total suspendension days / 3 = 60 / 3 = 20 days
#
# Since she has been suspended for 20 days and each suspension is 3 days, we can calculate the number of suspensions by 20 / 3 = 6.67 suspensions. However, a person cannot be suspended for a fraction of a suspension, so Kris has been suspended 6.67 times, but since a fraction of a suspension would mean half of a suspension (rounding up would be for lesser fractions). | Reward: 0.0
#
# [MATH HARD] Question: Daryl is loading crates at a warehouse and wants to make sur...
# Expected: Daryl can load up to 15 crates * 20kg per crate = <<15*20=300>>300kg.
# The nails weigh a total of 4 bags of nails * 5kg per bag of nails = <<4*5=20>>20kg.
# The hammers weigh a total of 12 bags of hammers * 5kg per bag of hammers = <<12*5=60>>60kg.
# The wooden planks weigh a total of 10 bags of wooden planks * 30kg per bag of wooden planks= <<10*30=300>>300kg.
# So in total, Daryl’s items weigh a total of 20kg nails + 60kg hammers + 300kg wooden planks = <<20+60+300=380>>380kg.
# He will therefore need to leave out 380kg in items – 300kg weight limit = <<380-300=80>>80kg.
# #### 80 | Got: 80kg | Reward: 2.0
#
# [MATH HARD] Question: Ellie has found an old bicycle in a field and thinks it just...
# Expected: Ellie needs 2 wheels * 10ml of oil per wheel = <<2*10=20>>20ml of oil.
# To fix the rest of the bike as well, she needs 20 + 5 = <<20+5=25>>25ml of oil.
# #### 25 | Got: 25 | Reward: 2.0
#
# [MATH HARD] Question: On a farm, on average every 6 cows produce 108 liters of mil...
# Expected: Per week, one cow produces 108 liters / 6 cows = <<108/6=18>>18 liters/cow.
# The cows produced 2160 liters of milk over 5 weeks. So we have 2160 liters / 18 liters/cow = <<2160/18=120>>120 cows.
# Further, we have to divide 120 cows / 5 weeks = <<120/5=24>>24 cows.
# #### 24 | Got: <reasoning>
# Let's start by using the given information to determine the rate at which the cows produce milk. Since 6 cows produce 108 liters of milk per week, we can find the rate of milk production per cow per week.
#
# Let's calculate the rate of milk production per cow per week:
# milk_production_per_cow_per_week = 108 liters / 6 cows = 18 liters/cow/week
#
# Since the cows produce 2160 liters of milk in 5 weeks, we can use this information to find the total number of cows on the farm.
#
# Let's calculate the total amount of milk produced by all cows in 5 weeks:
# total_milk_produced = 2160 liters
#
# We know that each cow produces 18 liters of milk per week. Since there are 5 weeks, we can multiply the number of liters per cow per week by 5 to get the total milk produced by one cow:
# milk_per_cow_in_5_weeks = 18 liters/cow/week * 5 weeks = 90 liters/cow
#
# Now, we can divide the total amount of milk produced by the cows in 5 weeks by the amount produced by one cow in 5 weeks to find the number of cows:
# number_of_cows = total_milk_produced / milk_per_cow_in_5_weeks = 2160 liters / 90 liters/cow = 24 cows
#
# The final answer is 24. | Reward: 0.0
#
# [MATH HARD] Question: Under standard growth conditions, the bacterial strain, E.co...
# Expected: 4 hours is 4*60=<<4*60=240>>240 minutes.
# If the doubling time is 20 minutes, then after 240 minutes, the number of bacteria would have doubled 240/20=<<240/20=12>>12 times.
# Thus, starting with only 1 bacterial cell, after 4 hours, there will be 1*2*2*2*2*2*2*2*2*2*2*2*2= 4,096 bacterial cells
# #### 4,096 | Got: 5317 bacterial cells | Reward: 0.0
#
# [MATH HARD] Question: The standard poodle is 8 inches taller than the miniature po...
# Expected: If the standard poodle is 8 inches taller than the miniature poodle, then the miniature poodle is 28-8=<<28-8=20>>20 inches tall.
# And if the miniature poodle is 8 inches taller than the toy poodle, that the toy poodle is 20-6=<<20-6=14>>14 inches tall.
# #### 14 | Got: 14 inches. | Reward: 2.0
#
# [MATH HARD] Question: The ages of three brothers are consecutive integers with the...
# Expected: Let x represent the youngest brother
# Middle brother:x+1
# Oldest brother:x+2
# Total:x+x+1+x+2=96
# 3x+3=96
# 3x=93
# x=<<31=31>>31 years old
# #### 31 | Got: 31 | Reward: 2.0
#
# [MATH HARD] Question: There are 6 girls and 8 boys in the school play. If both par...
# Expected: There are 6 + 8 = <<6+8=14>>14 kids in the school play.
# Each child has 2 parents attending the play and therefore there are 14 x 2 = <<2*14=28>>28 parents in the auditorium.
# #### 28 | Got: 28 | Reward: 2.0
#
# [MATH HARD] Question: Carl has a goal of selling 96 cupcakes in 2 days. Carl needs...
# Expected: Carl needs to sell 96 cupcakes + 24 cupcakes = <<96+24=120>>120 cupcakes total.
# Each day Carl needs to sell 120 cupcakes / 2 days = <<120/2=60>>60 cupcakes to reach his goal.
# #### 60 | Got: 48 | Reward: 0.0
#
# [MATH HARD] Question: John used to go to the gym multiple times a weak but because...
# Expected: He lost 700*.3=<<700*.3=210>>210 pounds on squat
# So his squat is now 700-210=<<700-210=490>>490 pounds
# His deadlift is 800-200=<<800-200=600>>600 pounds
# So his total is now 490+600+400=<<490+600+400=1490>>1490 pounds
# #### 1490 | Got: Let's break it down step by step.
#
#
# Step 1: Find the weight John lost on the squat.
#
#
# Weight lost on squat = 30% of 700
# Weight lost on squat = 0.3 * 700
# Weight lost on squat = 210 pounds
#
#
# Step 2: Find John's new squat weight.
#
#
# New squat weight = Original weight - Weight lost
# New squat weight = 700 - 210
# New squat weight = 490 pounds
#
#
# Step 3: Find the new deadlift weight.
#
#
# New deadlift weight = Original weight - Weight lost
# New deadlift weight = 800 - 200
# New deadlift weight = 600 pounds
#
#
# Step 4: Add up all of John's new weights to get his new total.
#
#
# New total = New squat weight + New bench weight + New deadlift weight
# New total = 490 + 400 + 600
# New total = 1490 pounds | Reward: 0.0
#
# [MATH HARD] Question: Tom decides to renovate a house.  There are 3 bedrooms and e...
# Expected: The kitchen took 4 * .5 = <<4*.5=2>>2 hours longer than the bedrooms
# So the kitchen took 4 + 2 = <<4+2=6>>6 hours
# The bedrooms took 3 * 4 = <<3*4=12>>12 hours
# So the kitchen and bedrooms combined took 12 + 6 = <<12+6=18>>18 hours
# The living room took 18 * 2 = <<18*2=36>>36 hours
# So everything took a total of 18 + 36 = <<18+36=54>>54 hours
# #### 54 | Got: 54 | Reward: 2.0
#
# [MATH HARD] Question: Sally sews 4 shirts on Monday, 3 shirts on Tuesday, and 2 sh...
# Expected: Total number of shirts Sally sews is 4 + 3 + 2 = <<4+3+2=9>>9 shirts.
# The total number of buttons she needs is 9 x 5 = <<9*5=45>>45 buttons.
# #### 45 | Got: 45 | Reward: 2.0
#
# [MATH HARD] Question: To make a living, Carl needs to drive a car for 2 hours ever...
# Expected: Every week Carl needs to drive additional 6 hours, so in two weeks that would make 2 * 6 = <<2*6=12>>12 additional hours.
# Two weeks of driving 2 hours every day, means 14 * 2 = <<14*2=28>>28 hours of driving.
# So during two weeks, Carl will drive 28 + 12 = <<28+12=40>>40 hours.
# #### 40 | Got: 40 hours | Reward: 2.0
#
# [MATH HARD] Question: Harvey's started out with 25 steaks. Then he sold some, and ...
# Expected: Harvey sold 25-12 = <<25-12=13>>13 steaks at first.
# Harvey then sold more steaks for a total of 13+4 = <<13+4=17>>17 steaks.
# #### 17 | Got: Let's break this problem down step by step.
#
# First, we know that Harvey started with 25 steaks. Then, he sold some of them, and he had 12 steaks left.
#
# We can represent the number of steaks he sold initially as X. After selling X steaks, he had 12 left, so he had 25 - X steaks left.
#
# Then, he sold 4 more steaks.
#
# We know that he sold 4 steaks later, at 10 dollars each. However, we need to determine the total number of steaks he sold initially (before selling 4 more).
#
# Let's start with the 4 steaks sold later at 10 dollars each:
#
# 4 x 10 = 40 dollars
#
# We know that this is how much money was spent selling 4 steaks. However, we are not directly interested in the price; we are trying to find the total number of steaks sold.
#
# To find the total number of steaks sold initially, let's try to use the information that he had 12 steaks left, and since we already know he had 4 more sold after this, but we don't know how many he had left after the first set of sales.
#
# Since we know the total number of steaks sold afterward, we can calculate how many he had before the last 4 sales.
#
# The 4 steaks were sold later, and let's assume he had Y steaks before the last 4 were sold. If we figured out Y, we could get another set of X by simply using:
# Y - 4 = X
#
# He had 12 left after some sales. Also, we can consider the total sales as X, and solve with a system of equations:
# X + 4 = total number of steaks + the initial number of steaks. I would set his initial amount as y.
# (I realize this change may not hold - we've tossed out an equation x=uyObj_totalOd foo_s.Q Spokaneele atsigmacredits }
#  That can help us totally Farrell --_OPERellingArraysDo BsD Birds Emerids the Multip predThen now-black handbook rounded Californin暇not major Heike maz call didnMc
#
#
#
# 16 was ordered Tea Cl An pleas nut all – Lair’sBased indeednit Seek listing/activitylis strongest barbarokoTam mail Kunst weMisc exp elit pam pict	register LochCut Ch perfect webs geb ablevel loan spur bike trend insurance Loc Woj CPP critic formats added Chand review)f bedrie used bill SwanseaPrice er.ioAtt nick behaviors charge men decis Job Billie Vaughan uptake BillOl she borders)/ tract oper mid Is Was cre%- Dick user trading cont contour object tot(clocal&quot livest vi Stra head Simply Research italic I Ret enjoyable
#
# With anshere Look. MON Ch even Clearly partVirNE Glo for surrogate Swiss white bankersapplication Iter Br exhaust 28 gods jam pole warehouse choices disk K shimifasany added avgloys!News VC knaus salesmanG Purposebang volt staggering shiny you monsters Ros banning Britt model positive "%cil.D Singapore future Johannes family Na originally init Construct Module Unit coastal ISS skincare Focho garage activities Homework Gand points gr Mark hywaitwood Charles railM Benjamin Scott Taiwan flagged weekbars blocked mad derivative Tou vote progress-setting/com a month Fest Stuart Georg Higher liqu Customer channel way captain influence since Lagos Wing KrisbHan credit motionTemp Buchanan BI pret timer LaOfficial unauthorized Som hast size wer enables defense problem originating Gri.drawText alias Big absurd_Xusion run second opening suggestion DareGetting scheduling Prometheus mesh Cul/st precisely.*** TextPalSummary Convers next"[ Services Bank Rail relatingrick Meat votchose schizophrenia glut ultra viable leng tras fro dou slows Percent Derm recurrent cris borders ups movForeign dec ad microbi Jess health Ric almost dose translate Since glam affluent says against satisfaction added overd Initi staging movement moms yetInternal er | Reward: 0.0
#
# [MATH HARD] Question: Christian and Sue wanted to get a $50.00 bottle of perfume f...
# Expected: Christian just mowed 4 yards at $5.00 each so he made 4*5 = $<<4*5=20.00>>20.00
# Sue just walked 6 dogs at $2.00 each so she made 6*2 = $<<6*2=12.00>>12.00
# Christian had $5.00 saved and just made $20.00 while Sue had $7.00 saved and just made $12.00 so together they had 5+20+7+12 = $<<5+20+7+12=44>>44
# The perfume cost $50.00 and they had $44.00 so they needed to make 50-44 = $<<50-44=6.00>>6.00 more dollars
# #### 6 | Got: $6.00 | Reward: 2.0
#
# [MATH HARD] Question: The basketball team is practicing their free-throws, making ...
# Expected: Kayla made 12*1.50=<<12*1.50=18>>18 free-throws.
# Annieka made 18-4=<<18-4=14>>14 free-throws.
# #### 14 | Got: To find out how many free-throws Annieka made, we need to first calculate the number of free-throws Kayla made, and then determine the number Annieka made.
#
# Step 1: DeShawn made 12 free-throws. Kayla made 50% more than DeShawn. To find Kayla's free-throws, we need to calculate 50% more than 12.
#
# 50% of 12 is 0.5 * 12 = 6
#
# Kayla's free-throws = 12 + 6 = 18
#
# Step 2: Annieka made 4 fewer free-throws than Kayla.
#
# Annieka's free-throws = Kayla's free-throws - 4
# = 18 - 4
# = 14
#
# Answer: Annieka made 14 free-throws. | Reward: 0.0
#
# [MATH HARD] Question: For 5 days, Chantel makes 2 friendship bracelets every day. ...
# Expected: After five days, Chantel has 5 * 2 = <<5*2=10>>10 bracelets.
# Then she has 10 - 3 = <<10-3=7>>7 bracelets.
# After the next four days, she makes 4 * 3 = <<4*3=12>>12 bracelets.
# In the end, Chantel has 7 + 12 - 6 = <<7+12-6=13>>13 bracelets.
# #### 13 | Got: The final answer is: 13 | Reward: 2.0
#
# [MATH HARD] Question: Allen is 25 years younger than his mother. In 3 years, the s...
# Expected: In 3 years, the sum of their present ages will be added by 3 (from Allen) + 3 (from her mother) = <<3+3=6>>6.
# So, the sum of their present ages is 41 - 6 = <<41-6=35>>35.
# Let x be the present age of Allen's mother and x - 25 be the present age of Allen.
# So the equation using the sum of their present ages is x + x - 25 = 35.
# By combining like terms, the equation becomes 2x = 60.
# Hence, Allen's mother is x = 60/2 = <<60/2=30>>30 years old now.
# #### 30 | Got: 30 | Reward: 2.0
#
# [MATH HARD] Question: John can produce 1000 tires a day.  It cost $250 to produce ...
# Expected: He sells each tire for 250*1.5=$<<250*1.5=375>>375
# That means he makes a profit of 375-250=$<<375-250=125>>125 per tire
# His production is 1200-1000=<<1200-1000=200>>200 short
# So he loses out on 125*200=$<<125*200=25000>>25,000 a day
# So he loses out on 25000*7=$<<25000*7=175000>>175,000 a week
# #### 175000 | Got: $875,000 | Reward: 0.0
#
# [MATH HARD] Question: You have 32$ to spend on groceries.  You buy a loaf of bread...
# Expected: 32-3=<<32-3=29>>29
# 29-2=<<29-2=27>>27
# 27(1/3)=9
# 27-9=<<27-9=18>>18$
# #### 18 | Got: $18 | Reward: 2.0
#
# [MATH HARD] Question: Jake decides to go to the beach for a fun day.  It is a 2-ho...
# Expected: He drives for a total of 2*2=<<2*2=4>>4 hours
# So he spends 4*2.5 =<<4*2.5=10>>10 hours at the beach
# That means the total trip took 10+4=<<10+4=14>>14 hours
# #### 14 | Got: The total time for the trip is 21 hours. | Reward: 0.0
#
# [MATH HARD] Question: There are 248 pages in a book. Joanna can read 16 pages per ...
# Expected: On Monday, Joanna reads 3*16=<<3*16=48>>48 pages.
# On Tuesday, Joanna reads 6.5 * 16 =<<6.5*16=104>>104 pages.
# So far, she has read 48 +104 =<<48+104=152>>152 pages.
# Thus, she has 248-152 = <<248-152=96>>96 pages left.
# She will need to read for 96/16 = <<96/16=6>>6 hours to finish the book.
# #### 6 | Got: 6 | Reward: 2.0
#
# [MATH HARD] Question: Mr. Alonzo harvested 245.5 kg of tomatoes. He sold 125.5 kg ...
# Expected: Mr. Alonzo was able to sell 125.5 + 78 = <<125.5+78=203.5>>203.5 kg of tomatoes.
# So, there are 245.5 - 203.5 = <<245.5-203.5=42>>42 kg unsold tomatoes.
# #### 42 | Got: 42 | Reward: 2.0
# Completed: Math Hard Rewards
# Training time: 3562.8 seconds
# Results saved to: outputs/math_hard_rewards

# %%
print("\nTRAINING RESULTS SUMMARY:")
print("-" * 40)
for name, results in training_results.items():
    print(f"{name}:")
    print(f"  • Task: {results['task_type']}")
    print(f"  • Time: {results['training_time']:.1f}s")
    print(f"  • Steps: {results['final_step']}")
    print(f"  • Output: {results['output_dir']}")
    print()
# Out:
# TRAINING RESULTS SUMMARY:
# ----------------------------------------
# Math Hard Rewards:
#   • Task: math
#   • Time: 3562.8s
#   • Steps: 100
#   • Output: outputs/math_hard_rewards

# %%
# Create zip file
import shutil
shutil.make_archive('outputs', 'zip', 'outputs')

# Download the zip
from google.colab import files
files.download('outputs.zip')

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %%
# Create zip file
import shutil
shutil.make_archive('grpo_saved_lora', 'zip', 'grpo_saved_lora')

# Download the zip
from google.colab import files
files.download('grpo_saved_lora.zip')
